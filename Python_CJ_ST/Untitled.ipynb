# %%
import pandas as pd

customerData = pd.read_csv("../dataset/customerdata.csv")
customerData.head(2)

# 컬럼 헤더 재설정
#customerData.colu,ns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 프레임 생성
#customerData = pd.DataFrame(customerData)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566    4273.90000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219    3642.44195    2          4.0    2.682023      Sleeping-dog

# %%
# EMI컬럼을 앞에 . 으로 쉽게 조건을 줄 수 있다. 
# .query 로도 가능

# %%
customerDataCleaned = customerData[(customerData.EMI==3)]

# %%
customerDataCleaned.head()
# Out:
#     CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27  F17131   3179.708359    3          6.5    1.100000        Early-bird
# 33  G16437   3787.328898    3          6.7    1.000000        Early-bird
# 36  G18402   3402.199381    3          6.5    1.000000        Early-bird
# 40  H16326   3988.935304    3          6.5    0.900000        Early-bird

# %% [markdown]
# ## 과제 kopo_customerdata 데이터에서 gender == male 이면서 email > 0 인 데이터를 추출하시오

# %%
customerData.dtypes
# 데이터의 타입들을 볼 수 있다.
# Out:
# CUSTOMERCODE      int64
# STATENAME        object
# ST                int64
# GENDER           object
# DOB               int64
# GENDER1           int64
# EMAIL             int64
# FEST_CNT          int64
# TOTAL_AMOUNT      int64
# AC_AMOUNT         int64
# AV_AMOUNT         int64
# HA_AMOUNT         int64
# EMI_CE_AMOUNT     int64
# IS_HIGHEND        int64
# CNT_VIST          int64
# GAP_VISIT         int64
# dtype: object

# %%
import pandas as pd

customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
customerData.head(2)
# Out:
#    CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2   Male    0        1      1         0
# 1       1190338    State2   2   Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0

# %%
#customerclean = customerData.query('GENDER == Male')
customerData.head()
customerData2 = customerData[(customerData.GENDER == "Male") & (customerData.EMAIL > 0) ] # 앞에 customerData가 빠지게 되면 해당 조건만 출력된다. 
customerData3 = customerData.query('GENDER == "Male" and EMAIL > 0')

customerData2
#customerData3
# Out:
#         CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2   Male    0        1      1         0
# 16           1154228    State2   2   Male    0        1      1         0
# 81            393246    State2   2   Male    0        1      1         1
# 206          2532568    State2   2   Male    1        1      1         0
# 216           487928    State2   2   Male    0        1      1         0
# 226          2452240    State2   2   Male    1        1      1         1
# 299          1295854    State2   2   Male    1        1      1         2
# 308           554757    State2   2   Male    0        1      1         0
# 330           761018    State2   2   Male    1        1      1         0
# 367          2191152    State2   2   Male    0        1      1         1
# 375           867914    State2   2   Male    0        1      1         0
# 415          1804886    State2   2   Male    0        1      1         1
# ...

# %% [markdown]
# ## kopo_product_volume 데이터에서 productgroup == ST0002 이면서 VOLUME > 300000 데이터를 추출하세요

# %%
import pandas as pd
customerData = pd.read_csv('../dataset/kopo_product_volume.csv')
customerData.head()

customerData2 = customerData[(customerData.PRODUCTGROUP.update "ST0002") & (customerData.VOLUME > 300000)]
customerData2
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 80       A01       ST0002    201452   422468
# 86       A01       ST0002    201451   356271
# 90       A01       ST0002    201449   669711
# 94       A01       ST0002    201447   378339
# 102      A01       ST0002    201448  1400339
# 196      A01       ST0002    201552   422468
# 208      A01       ST0002    201551   356271
# 212      A01       ST0002    201549   669711
# 216      A01       ST0002    201547   378339
# 224      A01       ST0002    201548  1400339

# %% [markdown]
# ## 데이터프레임 타입 변환

# %%
customerData.dtypes
customerData[(kopo_customerData.GENDER.astype(str).str.upper() == "Male")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ad1cd17c0c0f> in <module>()
#       1 customerData.dtypes
# ----> 2 customerData[(kopo_customerData.GENDER.astype(str).str.upper() == "Male")]
#
# NameError: name 'kopo_customerData' is not defined

# %%
a = "Male"
b = a.lower()
b = a.upper()
b
# Out:
# 'MALE'

# %% [markdown]
# ## 인덱스로 행 선택하기

# %%
customerData.head(5)
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# ...

# %%
#위에서 가장 좌측의 숫자가 index
df1 = customerData.iloc[0:3,0:1] #앞에것이 행, 뒤에것이 열 
print(df1)

df2 = customerData.iloc[0:3,1:]
print(df2)
# Out:
#   REGIONID
# 0      A01
# 1      A01
# 2      A01
#   PRODUCTGROUP  YEARWEEK  VOLUME
# 0       ST0001    201415  810144
# 1       ST0002    201415  128999
# 2       ST0001    201418  671464

# %% [markdown]
# ## 원하는 컬럼 조회하기

# %%
customerData[['PRODUCTGROUP','YEARWEEK']].head()
# Out:
#   PRODUCTGROUP  YEARWEEK
# 0       ST0001    201415
# 1       ST0002    201415
# 2       ST0001    201418
# 3       ST0002    201418
# 4       ST0001    201413

# %% [markdown]
# ## kopo_customerdata 테이블에서 customercode, statename, gender,total_amount 컬럼만 추출하자

# %%
import pandas as pd

customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
#customerData.head(2)

customerData2 = customerData[['CUSTOMERCODE','STATENAME','GENDER','TOTAL_AMOUNT']]
customerData2.head()
# Out:
#    CUSTOMERCODE STATENAME  GENDER  TOTAL_AMOUNT
# 0       1503989    State2    Male         30300
# 1       1190338    State2    Male         46500
# 2       1424715    State2  Female         22700
# 3       2483305    State2    Male         31400
# 4       1178802    State2    Male         44900

# %% [markdown]
# ## 인덱스로 조회하기

# %%
#customerData = customerData.iloc[0:3,:]
customerData
# Out:
#    CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2   Male    0        1      1         0
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0

# %% [markdown]
# ## kopo_customerdata 테이블에서 0~5번째 행의 statename, gender를 선택하세요(인덱스활용)

# %%
import pandas as pd

customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
#customerData.head(2)

#customerData.head()

customerData2 = customerData.iloc[0:6]
customerData3 = customerData2[['STATENAME','GENDER']]
customerData3

customerData2 = customerData.iloc[0:3,[1,3]] # 
customerData2
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female

# %% [markdown]
# ## 데이터 불러오기

# %%
stnameNo = customerData.columns.get_loc("STATENAME")
genderNo = customerData.columns.get_loc("GENDER")
stnameNo 
genderNo

#customerData.columns
# Out:
# 3

# %% [markdown]
# ## 이상 데이터 정제하기

# %%
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566    4273.90000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219    3642.44195    2          4.0    2.682023      Sleeping-dog

# %% [markdown]
# ## productage가 1보다 작으면 1 2보다 작으면 2 3보다 작으면 3 이외는 5라고 새로운 컬럼
# ## product_age_new를 생성하세요

# %%
import numpy as np
#customerData
import pandas as pd

customerData = pd.read_csv("../dataset/customerdata.csv")
#customerData.head(2)

customerData["product_age_new"] = np.where(customerData["PRODUCTAGE"] < 1 , 1 ,\
                                  np.where(customerData["PRODUCTAGE"] < 2 , 2 ,\
                                  np.where(customerData["PRODUCTAGE"] < 3 , 3 ,\
                                          5)))
customerData
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# ## 이상데이터 정제하기2

# %%
# 데이터 프레임을 함수로 받아서 사용하자!
import numpy as np
#customerData
import pandas as pd

customerData = pd.read_csv("../dataset/customerdata.csv")
#customerData.head(2)

def refining(df):
    if df['PRODUCTAGE'] < 1:
        return 1
    elif df['PRODUCTAGE'] < 2:
        return 2
    elif df['PRODUCTAGE'] < 3:
        return 3
    else:
        return 5

customerData["productage_new2"] = customerData.apply(refining,axis=1)
customerData
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# ## 데이터 정렬하기

# %%
customerData.sort_values(["EMI","AVERAGEPRICE"],ascending=[True,False],inplace=False)
customerData.head()
#정렬하는 순간 인덱스가 바뀌게 된다. 
#여기서 inplace를 쓰냐 안스냐에 따라 결과가 달라짐 
# inplace 를 한번 적용하고 끝낼지 계속 적용시킬지를 결정 
# 분석하다가 실제 잠깐 보고 마는 경우에는 디폴트값이 false 인데 true로 두게되면 한번 정렬되고 그 상태를 유지한 상태로 
# 데이터 값이 나오게 된다
# Out:
#     CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 56  K10712   3419.462596    1          4.4    2.825790      Sleeping-dog
# 72  O13037   3398.216334    1          4.5    2.994395      Sleeping-dog
# 46  I14835   3374.091339    1          4.0    2.749678      Sleeping-dog
# 65  M16452   3353.537290    1          4.0    1.940357      Sleeping-dog
# 11  C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
#
#     productage_new2
# 56                3
# 72                3
# 46                3
# 65                2
# 11                2

# %% [markdown]
# ## 데이터 요약분석하기

# %% [markdown]
# ## EMI별로 MAX값을 구하자

# %%
# 데이터 프레임을 함수로 받아서 사용하자!
import numpy as np
#customerData
import pandas as pd

customerData = pd.read_csv("../dataset/customerdata.csv")
#customerData.head(2)
customerData = customerData.groupby(['CUSTTYPE','EMI'],as_index=True).max()
customerData
# Out:
#                       CUSTID  AVERAGEPRICE  DEVICECOUNT  PRODUCTAGE
# CUSTTYPE         EMI
# Big-Screen-lover 1    C18622   3246.000000          5.0    1.891624
#                  2    Z16735   4165.700000          6.9    3.367229
#                  3    T11473   4273.900000          6.7    2.055707
# Early-bird       1    N14862   2390.083736          6.3    1.000000
#                  2    Z19835   4020.245162          6.9    1.300000
#                  3    Z13534   4296.873743          6.9    1.100000
# Sleeping-dog     1    Y12458   3419.462596          4.5    2.994395
#                  2    X19768   4166.533130          5.1    3.483573

# %% [markdown]
# ## 데이터 연산하기

# %%
# rolling
# 이동평균 구간정의
order = 5
import math 
suborder = math.floor(order/2)
suborder
# Out:
# 2

# %%
import numpy as np
#customerData
import pandas as pd

customerData = pd.read_csv("../dataset/customerdata.csv")
#연산
customerData["TEST"] = customerData["PRODUCTAGE"].rolling(window = 5,center = True,min_periods=1).mean()
customerData.head(10)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5  B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6  B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7  C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8  C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9  C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
#
#        TEST
# 0  2.523135
# 1  2.117351
# 2  2.184612
# 3  2.406109
# 4  2.049705
# 5  1.921030
# 6  2.155029
# 7  2.266986
# 8  2.332377
# 9  2.530702

# %% [markdown]
# ## 데이터 합치기

# %% [markdown]
# ## kopo_region_mst , kopo_channel_seasonality_new regionMasterData, selectExample 변수에 담으세요

# %%
import pandas as pd

region_mst = pd.read_csv("../dataset/kopo_region_mst.csv")
channel = pd.read_csv("C:/Users/cj/Python_Working/Python_CJ_ST/dataset/kopo_channel_seasonality_new.csv")

region_mst.head(2)
channel.head(2)

merge_Data = pd.merge(channel, region_mst,left_on="REGIONID",right_on = "REGIONID",how = 'left' )\
[["REGIONID","REGIONNAME","PRODUCT","YEARWEEK","QTY"]]
merge_Data.head() #조인 방법을 고려하자. 
# 어떻게 조인할것인지 정하는 how 라는 옵션이 있음 (left, right, inner)


merge_Data[merge_Data["REGIONNAME"].isnull()]

#NaN 이 null값 
#regionName이 null인 값이 있어서 조인 방법에 따라 결과값이 다르게 출력됨
# Out:
#        REGIONID REGIONNAME    PRODUCT  YEARWEEK      QTY
# 176         A77        NaN  PRODUCT12    201404   2628.0
# 177         A77        NaN   PRODUCT1    201404   1623.0
# 269         A77        NaN  PRODUCT12    201401   3821.0
# 270         A77        NaN   PRODUCT1    201401   3580.0
# 1728        A77        NaN  PRODUCT12    201402   2466.0
# 1729        A77        NaN   PRODUCT1    201402   2465.0
# 2711        A77        NaN  PRODUCT12    201405   1442.0
# 2712        A77        NaN   PRODUCT1    201405   1482.0
# 3096        A77        NaN  PRODUCT12    201403   2401.0
# 3097        A77        NaN   PRODUCT1    201403   2205.0
# 4105        A77        NaN  PRODUCT12    201406   3794.0
# 4106        A77        NaN   PRODUCT1    201406   4735.0
# 6259        A77        NaN  PRODUCT12    201407   2409.0
# 6260        A77        NaN   PRODUCT1    201407   3633.0
# 6653        A77        NaN  PRODUCT12    201409   2587.0
# ...

# %%
len(merge_Data)
# Out:
# 124658

# %% [markdown]
# ## 동일한 컬럼 데이터를 합치는 경우

# %%
import pandas as pd
import numpy as np

region_mst = pd.read_csv("../dataset/kopo_region_mst.csv")
channel = pd.read_csv("C:/Users/cj/Python_Working/Python_CJ_ST/dataset/kopo_channel_seasonality_new.csv")

#region_mst.head(2)
#channel.head(2)

#a01 데이터 정제 
a01data = channel[(channel['REGIONID'] == 'A01')]
a01data.head()
print(len(a01data))

#a71 데이터 정제 
a71data = channel[(channel['REGIONID'] == 'A71')]
a71data['QTY'] = np.where(a71data['QTY'] < 500,500,a71data['QTY'])
a71data
print(len(a71data))

mergedata = pd.concat([a01data,a71data],axis = 0)
mergedata

print(len(mergedata))
# Out:
# 3611
# 0
# 3611

# %%
region_mst.head(2)
# Out:
#   REGIONID REGIONNAME
# 0      A00     AFRICA
# 1      A01    AMERICA

# %%
channel.head(2)
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0

# %%
a71data
# Out:
# Empty DataFrame
# Columns: [REGIONID, PRODUCT, YEARWEEK, QTY, QTY_NEW]
# Index: []

# %%
a01data
# Out:
#        REGIONID    PRODUCT  YEARWEEK       QTY
# 47          A01  PRODUCT75    201403   23768.0
# 48          A01   PRODUCT8    201403     105.0
# 49          A01  PRODUCT19    201403    1513.0
# 50          A01  PRODUCT20    201403      59.0
# 51          A01  PRODUCT47    201403    4436.0
# 52          A01  PRODUCT60    201403       4.0
# 53          A01  PRODUCT56    201403    5449.0
# 54          A01  PRODUCT57    201403   13394.0
# 55          A01  PRODUCT12    201403  119281.0
# 56          A01   PRODUCT1    201403   21350.0
# 57          A01  PRODUCT33    201403    6940.0
# 58          A01  PRODUCT14    201403    8022.0
# 59          A01  PRODUCT62    201403    3823.0
# 492         A01   PRODUCT2    201401     225.0
# 493         A01   PRODUCT6    201401       0.0
# 494         A01  PRODUCT58    201401       0.0
# 495         A01  PRODUCT63    201401   47708.0
# 496         A01  PRODUCT15    201401    5684.0
# 497         A01   PRODUCT4    201401   18722.0
# ...
